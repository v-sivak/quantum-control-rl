# %%
import tensorflow as tf
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

import err_checks
import tf2_eager

# %%
# %matplotlib inline

# %%
tf.python.client.device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 6913341247561613714,
#  name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 2255126962464910465
#  physical_device_desc: "device: XLA_CPU device",
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 31732076416
#  locality {
#    bus_id: 2
#    numa_node: 1
#    links {
#    }
#  }
#  incarnation: 8266746114688171416
#  physical_device_desc: "device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:86:00.0, compute capability: 7.0",
#  name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 12608860627949963493
#  physical_device_desc: "device: XLA_GPU device"]

# %% [markdown]
# # Distribution Plots

# %%
def generate_coherent_states(N, alpha):
    displs = tf.cast(tf.linspace(tf.constant(0, dtype=tf.float64), np.pi, 100), dtype=tf.complex128)
    displs = tf.map_fn(lambda theta: np.abs(alpha) * tf.math.exp(1j * theta), displs)
    
    analytic = err_checks.coherent_analytic(N, displs)
        
    bch_time, bch_op = tf2_eager.eager_benchmark_BCH(N, displs, '/device:GPU:0', rep=1)
    numeric_bch = err_checks.coherent(bch_op)
    
    expm_time, op = tf2_eager.eager_benchmark(N, displs, '/device:GPU:0', rep=1)
    numeric = err_checks.coherent(op)
    
    return analytic, numeric_bch, numeric, bch_time, expm_time

# %%
def log_abs_err(test, ref):
    abs_err = tf.math.abs(test - ref)
    log10 = tf.math.log(tf.constant(10, dtype=tf.float64))
    log_abs_err = tf.clip_by_value(tf.math.log(abs_err) / log10, -38, 0)
    return abs_err, log_abs_err

# %%
def log_rel_err(test, ref):
    rel_err = tf.clip_by_value(tf.math.divide_no_nan(tf.math.abs(test - ref), tf.math.abs(ref)), 1e-8, 10)
    log10 = tf.math.log(tf.constant(10, dtype=tf.float64))
    log_rel_err = tf.math.log(rel_err) / log10
    return rel_err, log_rel_err

# %%
def plot_abs_err(N, alpha):
    analytic, numeric_bch, numeric, bch_time, expm_time = generate_coherent_states(N, alpha)
    print("Expm:", expm_time)
    print("BCH:", bch_time)

    _, n_err = log_abs_err(numeric, analytic)
    _, nbch_err = log_abs_err(numeric_bch, analytic)
    
    _, n_err_r = log_rel_err(numeric, analytic)
    _, nbch_err_r = log_rel_err(numeric_bch, analytic)

    comb = tf.concat([n_err, nbch_err], axis=0)
    vmax = tf.reduce_max(tf.boolean_mask(comb, tf.math.is_finite(comb)))
    vmin = tf.reduce_min(tf.boolean_mask(comb, tf.math.is_finite(comb)))
    
    comb_r = tf.concat([n_err_r, nbch_err_r], axis=0)
    vmax_r = tf.reduce_max(tf.boolean_mask(comb_r, tf.math.is_finite(comb_r)))
    vmin_r = tf.reduce_min(tf.boolean_mask(comb_r, tf.math.is_finite(comb_r)))
    
    fig = plt.figure(figsize=(15, 12))
    ax0 = fig.add_subplot(311)
    ax1 = fig.add_subplot(323)
    ax2 = fig.add_subplot(324)
    ax3 = fig.add_subplot(325)
    ax4 = fig.add_subplot(326)

    im1 = ax1.imshow(n_err, interpolation='nearest', aspect=0.5 * N / 100, vmin=vmin, vmax=vmax)
    im2 = ax2.imshow(nbch_err, interpolation='nearest', aspect=0.5 * N / 100, vmin=vmin, vmax=vmax)
    cb1 = fig.colorbar(im1, ax=[ax1, ax2])
    cb1.set_label('Log Absolute Error')
    ax1.set_title('Expm')
    ax2.set_title('BCH')
    
    im3 = ax3.imshow(n_err_r, interpolation='nearest', aspect=0.5 * N / 100, vmin=vmin_r, vmax=vmax_r,)
    im4 = ax4.imshow(nbch_err_r, interpolation='nearest', aspect=0.5 * N / 100, vmin=vmin_r, vmax=vmax_r)
    cb2 = fig.colorbar(im3, ax=[ax3, ax4])
    cb2.set_label('Log Relative Error')
    ax3.set_title('Expm (Relative)')
    ax4.set_title('BCH (Relative)')

    proba = tf.reduce_mean(tf.cast(tf.math.conj(analytic) * analytic, dtype=tf.float32), axis=0)
    probn = tf.reduce_mean(tf.cast(tf.math.conj(numeric) * numeric, dtype=tf.float32), axis=0)
    probbch = tf.reduce_mean(tf.cast(tf.math.conj(numeric_bch) * numeric_bch, dtype=tf.float32), axis=0)
    ax0.plot(proba, label='Analytic')
    ax0.plot(probn, label='Expm')
    ax0.plot(probbch, label='BCH')
    ax0.set_yscale("log")
    ax0.set_ylabel('Log Prob')
    ax0.legend()
    fig.suptitle('N = %i, α = %i' % (N, alpha), y=0.92, fontsize=16)

# %%
plot_abs_err(50, 1)
# Out:
# Expm: 0.009347770363092422
# BCH: 0.0019696038216352463

# %%
plot_abs_err(50, 3)
# Out:
# Expm: 0.004860203713178635
# BCH: 0.0008006077259778976

# %%
plot_abs_err(50, 10)
# Out:
# Expm: 0.005244268104434013
# BCH: 0.000805240124464035

# %%
plot_abs_err(100, 1)
# Out:
# Expm: 0.006386391818523407
# BCH: 0.0007983185350894928

# %%
plot_abs_err(100, 3)
# Out:
# Expm: 0.007223092019557953
# BCH: 0.0007900483906269073

# %%
plot_abs_err(100, 10)
# Out:
# Expm: 0.0075591374188661575
# BCH: 0.0007953457534313202

# %%
plot_abs_err(500, 1)
# Out:
# Expm: 0.270940825343132
# BCH: 0.0008492115885019302

# %%
plot_abs_err(500, 3)
# Out:
# Expm: 0.2717215530574322
# BCH: 0.0008566528558731079

# %%
plot_abs_err(500, 10)
# Out:
# Expm: 0.2958189006894827
# BCH: 0.000958021730184555

# %%
plot_abs_err(1000, 1)
# Out:
# Expm: 1.8287344444543123
# BCH: 0.0009260755032300949

# %%
plot_abs_err(1000, 3)
# Out:
# Expm: 1.932300839573145
# BCH: 0.0009405016899108887

# %%
plot_abs_err(1000, 10)
# Out:
# Expm: 2.0294077955186367
# BCH: 0.0009057596325874329

# %% [markdown]
# # Commutator Expectation

# %%
def commutator_exp(state):
    a = tf.linalg.diag(tf.sqrt(tf.range(1, state.shape[1], dtype=tf.float64)), k=1)
    a = tf.cast(a, dtype=tf.complex128)
    a_dag = tf.linalg.adjoint(a)
    commutator = a @ a_dag - a_dag @ a
    
    one = tf.constant(1., dtype=tf.float64)
    exp = tf.math.abs(tf.reduce_sum(tf.math.conj(state) * tf.linalg.matvec(commutator, state), 1))
    return one - exp

# %%
def generate_coherent_states_sweep(N, phase):
    displs = tf.cast(tf.linspace(tf.constant(0, dtype=tf.float64), 7, 100), dtype=tf.complex128)
    displs = tf.map_fn(lambda mag: tf.cast(np.abs(mag) * tf.math.exp(1j * phase), dtype=tf.complex128), displs)
    analytic = err_checks.coherent_analytic(N, displs)
        
    _, bch_op = tf2_eager.eager_benchmark_BCH(N, displs, '/device:CPU:0', rep=1)
    numeric_bch = err_checks.coherent(bch_op)
    
    _, op = tf2_eager.eager_benchmark(N, displs, '/device:CPU:0', rep=1)
    numeric = err_checks.coherent(op)
    
    return analytic, numeric_bch, numeric

# %%
for N in [100, 250]:
    analytic, numeric_bch, numeric = generate_coherent_states_sweep(N, 0)
#     plt.plot(np.linspace(0, 10, 100), commutator_exp(analytic), label='Analytic-%i' % N)
    plt.plot(np.linspace(0, 8, 100), commutator_exp(numeric), label='Expm-%i' % N)
    plt.plot(np.linspace(0, 8, 100), commutator_exp(numeric_bch), label='BCH-%i' % N)
ax = plt.gca()
# ax.set_yscale('log')
plt.legend()
fig = plt.gcf()
fig.set_size_inches(15, 10)
